# %%
#1
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

tf.logging.set_verbosity(tf.logging.ERROR)
old_v = tf.logging.get_verbosity()

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

#2
total_epoch =100
batch_size = 100
learning_rate = 0.0002
n_hidden = 256
n_input = 28 * 28
n_noise = 128

#3
X=tf.placeholder(tf.float32, [None, n_input])
Z=tf.placeholder(tf.float32, [None, n_noise])

#4
G_W1 = tf.Variable(tf.random_normal([n_noise,n_hidden], stddev=0.01))
G_b1 = tf.Variable(tf.zeros([n_hidden]))
G_W2 = tf.Variable(tf.random_normal([n_hidden,n_input], stddev=0.01))
G_b2 = tf.Variable(tf.zeros([n_input]))

#5
D_W1 = tf.Variable(tf.random_normal([n_input,n_hidden], stddev=0.01))
D_b1 = tf.Variable(tf.zeros([n_hidden]))
D_W2 = tf.Variable(tf.random_normal([n_hidden,1], stddev=0.01))
D_b2 = tf.Variable(tf.zeros([1]))

#6
def generator(noise_z):
    hidden = tf.nn.relu(tf.matmul(noise_z, G_W1) + G_b1)
    
    output = tf.nn.sigmoid(tf.matmul(hidden, G_W2) + G_b2)
    
    return output

#7
def discriminator(inputs):
    hidden = tf.nn.relu(tf.matmul(inputs, D_W1) + D_b1)
    
    output = tf.nn.sigmoid(tf.matmul(hidden, D_W2) + D_b2)
    
    return output

#8
def get_noise(batch_size, n_noise):
    return np.random.normal(size=(batch_size,n_noise))

#9
G= generator(Z)
D_gene = discriminator(G)
D_real = discriminator(X)

#10
loss_D = tf.reduce_mean(tf.log(D_real) + tf.log(1 - D_gene))
loss_G = tf.reduce_mean(tf.log(D_gene))

#11
D_var_list = [D_W1, D_b1, D_W2, D_b2]
G_var_list = [G_W1, G_b1, G_W2, G_b2]

train_D = tf.train.AdamOptimizer(learning_rate).minimize(-loss_D, var_list = D_var_list)
train_G = tf.train.AdamOptimizer(learning_rate).minimize(-loss_G, var_list = G_var_list)

#12
sess = tf.Session()
sess.run(tf.global_variables_initializer())

total_batch = int(mnist.train.num_examples / batch_size)
loss_val_D, loss_val_G = 0, 0

for epoch in range(total_epoch):
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        noise = get_noise(batch_size, n_noise)
        
        _,loss_val_D = sess.run([train_D, loss_D],
                               feed_dict={X: batch_xs, Z: noise})
        _,loss_val_G = sess.run([train_G, loss_G],
                               feed_dict={Z:noise})
        
    print('Epoch', '%04d' % epoch,
             'D loss: {:.4}'.format(loss_val_D),
             'G loss: {:.4}'.format(loss_val_G))
        
        
    #13
    if epoch == 0 or (epoch+1) %10 == 0 :
        sample_size = 10
        noise = get_noise(sample_size, n_noise)
        samples = sess.run(G, feed_dict={Z:noise})
        
        fig, ax = plt.subplots(1, sample_size, figsize=(sample_size, 1))
        
        for i in range(sample_size):
            ax[i].set_axis_off()
            ax[i].imshow(np.reshape(samples[i],(28,28)))
            
        plt.savefig('samples/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
            
        plt.close(fig)
            
            
print('최적화 완료!')
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# Epoch 0000 D loss: -0.5579 G loss: -1.967
# Epoch 0001 D loss: -0.531 G loss: -2.195
# Epoch 0002 D loss: -0.4673 G loss: -2.145
# Epoch 0003 D loss: -0.4874 G loss: -1.545
# Epoch 0004 D loss: -0.458 G loss: -1.607
# Epoch 0005 D loss: -0.2484 G loss: -2.332
# Epoch 0006 D loss: -0.257 G loss: -2.734
# Epoch 0007 D loss: -0.4369 G loss: -2.598
# Epoch 0008 D loss: -0.4283 G loss: -2.056
# Epoch 0009 D loss: -0.5727 G loss: -1.884
# Epoch 0010 D loss: -0.4541 G loss: -2.072
# Epoch 0011 D loss: -0.4226 G loss: -2.094
# Epoch 0012 D loss: -0.5529 G loss: -2.01
# Epoch 0013 D loss: -0.4568 G loss: -2.071
# Epoch 0014 D loss: -0.4267 G loss: -2.107
# Epoch 0015 D loss: -0.5896 G loss: -1.913
# Epoch 0016 D loss: -0.6754 G loss: -1.818
# Epoch 0017 D loss: -0.5717 G loss: -1.962
# Epoch 0018 D loss: -0.642 G loss: -2.03
# Epoch 0019 D loss: -0.7342 G loss: -1.63
# Epoch 0020 D loss: -0.7539 G loss: -1.815
# Epoch 0021 D loss: -0.6405 G loss: -1.73
# Epoch 0022 D loss: -0.7341 G loss: -1.811
# Epoch 0023 D loss: -0.8449 G loss: -1.748
# Epoch 0024 D loss: -0.7515 G loss: -1.619
# Epoch 0025 D loss: -0.5461 G loss: -2.108
# Epoch 0026 D loss: -0.5254 G loss: -1.871
# Epoch 0027 D loss: -0.6176 G loss: -1.946
# Epoch 0028 D loss: -0.5857 G loss: -1.961
# Epoch 0029 D loss: -0.5754 G loss: -1.97
# Epoch 0030 D loss: -0.7363 G loss: -2.035
# Epoch 0031 D loss: -0.6934 G loss: -1.898
# Epoch 0032 D loss: -0.6805 G loss: -1.741
# Epoch 0033 D loss: -0.7972 G loss: -2.047
# Epoch 0034 D loss: -0.7571 G loss: -1.872
# Epoch 0035 D loss: -0.7589 G loss: -1.895
# Epoch 0036 D loss: -0.533 G loss: -1.948
# Epoch 0037 D loss: -0.5147 G loss: -2.112
# Epoch 0038 D loss: -0.6421 G loss: -1.983
# Epoch 0039 D loss: -0.7829 G loss: -1.804
# Epoch 0040 D loss: -0.953 G loss: -1.65
# Epoch 0041 D loss: -0.715 G loss: -1.783
# Epoch 0042 D loss: -0.6875 G loss: -1.89
# Epoch 0043 D loss: -0.6432 G loss: -1.904
# Epoch 0044 D loss: -0.822 G loss: -1.617
# Epoch 0045 D loss: -0.9573 G loss: -1.886
# Epoch 0046 D loss: -0.9034 G loss: -1.752
# Epoch 0047 D loss: -0.7334 G loss: -1.733
# Epoch 0048 D loss: -0.94 G loss: -1.746
# Epoch 0049 D loss: -0.8171 G loss: -1.679
# Epoch 0050 D loss: -0.9154 G loss: -1.693
# Epoch 0051 D loss: -0.6657 G loss: -1.749
# Epoch 0052 D loss: -1.066 G loss: -1.682
# Epoch 0053 D loss: -0.9471 G loss: -1.531
# Epoch 0054 D loss: -0.9075 G loss: -1.456
# Epoch 0055 D loss: -0.9231 G loss: -1.581
# Epoch 0056 D loss: -1.001 G loss: -1.355
# Epoch 0057 D loss: -0.9405 G loss: -1.614
# Epoch 0058 D loss: -1.244 G loss: -1.388
# Epoch 0059 D loss: -0.9228 G loss: -1.625
# Epoch 0060 D loss: -1.024 G loss: -1.582
# Epoch 0061 D loss: -1.097 G loss: -1.379
# Epoch 0062 D loss: -0.9707 G loss: -1.547
# Epoch 0063 D loss: -0.9276 G loss: -1.539
# Epoch 0064 D loss: -1.038 G loss: -1.522
# Epoch 0065 D loss: -1.003 G loss: -1.387
# Epoch 0066 D loss: -0.9589 G loss: -1.313
# Epoch 0067 D loss: -1.045 G loss: -1.329
# Epoch 0068 D loss: -1.034 G loss: -1.348
# Epoch 0069 D loss: -0.9858 G loss: -1.57
# Epoch 0070 D loss: -1.045 G loss: -1.398
# Epoch 0071 D loss: -1.039 G loss: -1.552
# Epoch 0072 D loss: -0.959 G loss: -1.29
# Epoch 0073 D loss: -0.9571 G loss: -1.482
# Epoch 0074 D loss: -1.016 G loss: -1.428
# Epoch 0075 D loss: -1.055 G loss: -1.311
# Epoch 0076 D loss: -1.115 G loss: -1.469
# Epoch 0077 D loss: -1.022 G loss: -1.41
# Epoch 0078 D loss: -1.123 G loss: -1.2
# Epoch 0079 D loss: -0.9621 G loss: -1.321
# Epoch 0080 D loss: -0.9163 G loss: -1.5
# Epoch 0081 D loss: -1.083 G loss: -1.439
# Epoch 0082 D loss: -0.8484 G loss: -1.539
# Epoch 0083 D loss: -1.152 G loss: -1.148
# Epoch 0084 D loss: -0.9207 G loss: -1.387
# Epoch 0085 D loss: -0.991 G loss: -1.502
# Epoch 0086 D loss: -0.9347 G loss: -1.266
# Epoch 0087 D loss: -0.9805 G loss: -1.417
# Epoch 0088 D loss: -0.8977 G loss: -1.357
# Epoch 0089 D loss: -0.826 G loss: -1.613
# Epoch 0090 D loss: -0.9118 G loss: -1.406
# Epoch 0091 D loss: -0.9615 G loss: -1.496
# Epoch 0092 D loss: -0.9231 G loss: -1.456
# Epoch 0093 D loss: -0.9717 G loss: -1.439
# Epoch 0094 D loss: -1.037 G loss: -1.41
# Epoch 0095 D loss: -0.9025 G loss: -1.366
# Epoch 0096 D loss: -0.9667 G loss: -1.46
# Epoch 0097 D loss: -1.01 G loss: -1.516
# Epoch 0098 D loss: -0.949 G loss: -1.456
# Epoch 0099 D loss: -1.008 G loss: -1.419
# 최적화 완료!
