# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

tf.logging.set_verbosity(tf.logging.ERROR)
old_v = tf.logging.get_verbosity()

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

#1
total_epoch =100
batch_size = 100
n_hidden = 256
n_input = 28 * 28
n_noise = 128
n_class = 10


X=tf.placeholder(tf.float32, [None, n_input])
Y=tf.placeholder(tf.float32, [None, n_class])
Z=tf.placeholder(tf.float32, [None, n_noise])

#2
def generator(noise, labels):
    with tf.variable_scope('generator'):
        inputs = tf.concat([noise, labels], 1)
        
        hidden = tf.layers.dense(inputs, n_hidden, activation=tf.nn.relu)
    
        output = tf.layers.dense(hidden, n_input, activation=tf.nn.sigmoid)
    
    return output

#3
def discriminator(inputs, labels, reuse=None):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
            
        inputs = tf.concat([inputs, labels], 1)
            
        hidden = tf.layers.dense(inputs, n_hidden, activation= tf.nn.relu)
            
        output = tf.layers.dense(hidden, 1, activation=None)
    
    return output

#4
def get_noise(batch_size, n_noise):
    return np.random.normal(-1., 1., size=(batch_size,n_noise))

#5
G= generator(Z, Y)
D_real = discriminator(X, Y)
D_gene = discriminator(G, Y, True)

#6
loss_D_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
    logits = D_real, labels= tf.ones_like(D_real)))
loss_D_gene = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
    logits = D_gene, labels=tf.zeros_like(D_gene)))

loss_D = loss_D_real + loss_D_gene

#7
loss_G = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
    logits = D_gene, labels=tf.ones_like(D_gene)))

#8
vars_D = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                          scope='discriminator')
vars_G = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                          scope='generator')

train_D = tf.train.AdamOptimizer().minimize(loss_D, var_list = vars_D)
train_G = tf.train.AdamOptimizer().minimize(loss_G, var_list = vars_G)

#9
sess = tf.Session()
sess.run(tf.global_variables_initializer())

total_batch = int(mnist.train.num_examples / batch_size)
loss_val_D, loss_val_G = 0, 0

for epoch in range(total_epoch):
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        noise = get_noise(batch_size, n_noise)
        
        _,loss_val_D = sess.run([train_D, loss_D],
                               feed_dict={X: batch_xs, Y: batch_ys, Z: noise})
        _,loss_val_G = sess.run([train_G, loss_G],
                               feed_dict={Y: batch_ys, Z:noise})
        
    print('Epoch', '%04d' % epoch,
             'D loss: {:.4}'.format(loss_val_D),
             'G loss: {:.4}'.format(loss_val_G))
        
        
    #13
    if epoch == 0 or (epoch+1) %10 == 0 :
        sample_size = 10
        noise = get_noise(sample_size, n_noise)
        samples = sess.run(G, feed_dict={Y: mnist.test.labels[:sample_size], Z:noise})
        
        fig, ax = plt.subplots(2, sample_size, figsize=(sample_size, 2))
        
        for i in range(sample_size):
            ax[0][i].set_axis_off()
            ax[1][i].set_axis_off()
            ax[0][i].imshow(np.reshape(mnist.test.images[i],(28,28)))
            ax[1][i].imshow(np.reshape(samples[i],(28,28)))
            
        plt.savefig('samples2/{}.png'.format(str(epoch).zfill(3)), bbox_inches='tight')
            
        plt.close(fig)
            
            
print('최적화 완료!')
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# Epoch 0000 D loss: 0.0006292 G loss: 8.024
# Epoch 0001 D loss: 0.0001405 G loss: 10.0
# Epoch 0002 D loss: 9.381e-05 G loss: 10.89
# Epoch 0003 D loss: 3.788e-05 G loss: 11.17
# Epoch 0004 D loss: 0.0001135 G loss: 10.0
# Epoch 0005 D loss: 8.602e-06 G loss: 12.01
# Epoch 0006 D loss: 0.0002086 G loss: 8.903
# Epoch 0007 D loss: 0.0001388 G loss: 9.286
# Epoch 0008 D loss: 0.0002104 G loss: 11.21
# Epoch 0009 D loss: 2.76e-05 G loss: 11.94
# Epoch 0010 D loss: 6.281e-06 G loss: 13.3
# Epoch 0011 D loss: 2.079e-06 G loss: 13.53
# Epoch 0012 D loss: 1.567e-06 G loss: 14.34
# Epoch 0013 D loss: 1.056e-06 G loss: 14.69
# Epoch 0014 D loss: 1.478e-06 G loss: 15.12
# Epoch 0015 D loss: 2.464e-07 G loss: 15.6
# Epoch 0016 D loss: 3.612e-07 G loss: 15.21
# Epoch 0017 D loss: 1.443e-06 G loss: 14.67
# Epoch 0018 D loss: 3.646e-06 G loss: 13.88
# Epoch 0019 D loss: 5.662e-07 G loss: 15.49
# Epoch 0020 D loss: 1.191e-07 G loss: 16.48
# Epoch 0021 D loss: 1.731e-07 G loss: 16.3
# Epoch 0022 D loss: 7.881e-08 G loss: 16.88
# Epoch 0023 D loss: 5.49e-08 G loss: 17.56
# Epoch 0024 D loss: 3.921e-08 G loss: 17.84
# Epoch 0025 D loss: 2.652e-08 G loss: 18.29
# Epoch 0026 D loss: 3.952e-08 G loss: 18.84
# Epoch 0027 D loss: 2.348e-08 G loss: 19.27
# Epoch 0028 D loss: 4.35e-08 G loss: 17.6
# Epoch 0029 D loss: 9.463e-08 G loss: 19.69
# Epoch 0030 D loss: 5.538e-09 G loss: 19.79
# Epoch 0031 D loss: 9.016e-08 G loss: 20.4
# Epoch 0032 D loss: 4.675e-08 G loss: 20.62
# Epoch 0033 D loss: 3.978e-09 G loss: 20.88
# Epoch 0034 D loss: 1.392e-09 G loss: 21.41
# Epoch 0035 D loss: 5.422e-10 G loss: 21.64
# Epoch 0036 D loss: 9.996e-10 G loss: 21.92
# Epoch 0037 D loss: 3.448e-09 G loss: 22.25
# Epoch 0038 D loss: 2.3e-10 G loss: 22.59
# Epoch 0039 D loss: 7.633e-10 G loss: 22.75
# Epoch 0040 D loss: 1.903e-10 G loss: 23.06
# Epoch 0041 D loss: 6.373e-10 G loss: 23.25
# Epoch 0042 D loss: 1.186e-10 G loss: 23.54
# Epoch 0043 D loss: 6.434e-11 G loss: 23.81
# Epoch 0044 D loss: 1.095e-10 G loss: 23.9
# Epoch 0045 D loss: 5.05e-11 G loss: 24.2
# Epoch 0046 D loss: 7.583e-11 G loss: 23.83
# Epoch 0047 D loss: 3.889e-10 G loss: 24.39
# Epoch 0048 D loss: 1.814e-10 G loss: 24.61
# Epoch 0049 D loss: 4.637e-11 G loss: 24.8
# Epoch 0050 D loss: 7.761e-11 G loss: 24.98
# Epoch 0051 D loss: 4.197e-11 G loss: 24.4
# Epoch 0052 D loss: 2.81e-11 G loss: 25.05
# Epoch 0053 D loss: 1.933e-10 G loss: 24.42
# Epoch 0054 D loss: 2.241e-11 G loss: 24.96
# Epoch 0055 D loss: 8.665e-11 G loss: 25.35
# Epoch 0056 D loss: 3.017e-11 G loss: 25.47
# Epoch 0057 D loss: 1.166e-11 G loss: 25.64
# Epoch 0058 D loss: 1.613e-11 G loss: 25.83
# Epoch 0059 D loss: 8.762e-12 G loss: 25.91
# Epoch 0060 D loss: 9.923e-12 G loss: 26.13
# Epoch 0061 D loss: 1.106e-11 G loss: 26.19
# Epoch 0062 D loss: 9.391e-12 G loss: 26.28
# Epoch 0063 D loss: 3.196e-11 G loss: 26.33
# Epoch 0064 D loss: 1.074e-11 G loss: 26.55
# Epoch 0065 D loss: 3.419e-11 G loss: 26.59
# Epoch 0066 D loss: 3.09e-11 G loss: 24.53
# Epoch 0067 D loss: 7.143e-12 G loss: 26.01
# Epoch 0068 D loss: 9.993e-12 G loss: 25.97
# Epoch 0069 D loss: 3.835e-11 G loss: 26.22
# Epoch 0070 D loss: 7.574e-12 G loss: 26.56
# Epoch 0071 D loss: 5.167e-12 G loss: 26.66
# Epoch 0072 D loss: 4.383e-12 G loss: 26.71
# Epoch 0073 D loss: 5.244e-11 G loss: 26.8
# Epoch 0074 D loss: 6.937e-12 G loss: 26.78
# Epoch 0075 D loss: 8.637e-12 G loss: 26.96
# Epoch 0076 D loss: 5.382e-12 G loss: 27.06
# Epoch 0077 D loss: 2.619e-12 G loss: 26.94
# Epoch 0078 D loss: 2.552e-11 G loss: 24.65
# Epoch 0079 D loss: 1.688e-11 G loss: 25.98
# Epoch 0080 D loss: 1.677e-11 G loss: 26.54
# Epoch 0081 D loss: 4.895e-12 G loss: 26.68
# Epoch 0082 D loss: 1.055e-11 G loss: 26.76
# Epoch 0083 D loss: 2.962e-12 G loss: 26.93
# Epoch 0084 D loss: 2.741e-12 G loss: 26.96
# Epoch 0085 D loss: 2.87e-12 G loss: 26.96
# Epoch 0086 D loss: 2.634e-12 G loss: 27.16
# Epoch 0087 D loss: 2.881e-11 G loss: 26.59
# Epoch 0088 D loss: 1.981e-11 G loss: 25.1
# Epoch 0089 D loss: 9.767e-12 G loss: 25.73
# Epoch 0090 D loss: 4.169e-11 G loss: 26.26
# Epoch 0091 D loss: 4.764e-11 G loss: 26.42
# Epoch 0092 D loss: 1.572e-11 G loss: 26.73
# Epoch 0093 D loss: 1.08e-11 G loss: 26.8
# Epoch 0094 D loss: 5.904e-12 G loss: 26.41
# Epoch 0095 D loss: 7.775e-12 G loss: 26.63
# Epoch 0096 D loss: 8.735e-12 G loss: 26.78
# Epoch 0097 D loss: 3.208e-12 G loss: 26.94
# Epoch 0098 D loss: 7.085e-12 G loss: 27.09
# Epoch 0099 D loss: 2.881e-12 G loss: 27.02
# 최적화 완료!
